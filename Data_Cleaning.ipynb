# %% [markdown]
# # CUSTOMERS

# %%
import pandas as pd
import numpy as np
import datetime as dt
import matplotlib.pyplot as plt
import seaborn as sns
import mysql.connector

path=r'C:\Users\YAMINI RAVICHANDRAN\Documents\EDA\Customers.csv'
customer_dt=pd.read_csv(path,encoding='latin-1')
customer_dt
# Out:
#        CustomerKey  Gender               Name                 City State Code  \
# 0              301  Female      Lilly Harding       WANDEARAH EAST         SA
# 1              325  Female       Madison Hull           MOUNT BUDD         WA
# 2              554  Female      Claire Ferres            WINJALLOK        VIC
# 3              786    Male  Jai Poltpalingada         MIDDLE RIVER         SA
# 4             1042    Male    Aidan Pankhurst        TAWONGA SOUTH        VIC
# ...            ...     ...                ...                  ...        ...
# 15261      2099600  Female     Denisa Duková              Houston         TX
# 15262      2099618    Male   Justin Solórzano               Mclean         VA
# 15263      2099758    Male    Svend Petrussen           Wilmington         NC
# 15264      2099862  Female       Lorenza Rush            Riverside         CA
# 15265      2099937    Male   Zygmunt Kaminski  Bloomfield Township         MI
#
# ...

# %%
customer_dt.isnull().sum()
# Out:
# CustomerKey     0
# Gender          0
# Name            0
# City            0
# State Code     10
# State           0
# Zip Code        0
# Country         0
# Continent       0
# Birthday        0
# dtype: int64

# %%
customer_dt.columns
# Out:
# Index(['CustomerKey', 'Gender', 'Name', 'City', 'State Code', 'State',
#        'Zip Code', 'Country', 'Continent', 'Birthday'],
#       dtype='object')

# %%
customer_dt.drop(['State Code','Zip Code'],axis=1,inplace=True)
customer_dt
# Out:
#        CustomerKey  Gender               Name                 City  \
# 0              301  Female      Lilly Harding       WANDEARAH EAST
# 1              325  Female       Madison Hull           MOUNT BUDD
# 2              554  Female      Claire Ferres            WINJALLOK
# 3              786    Male  Jai Poltpalingada         MIDDLE RIVER
# 4             1042    Male    Aidan Pankhurst        TAWONGA SOUTH
# ...            ...     ...                ...                  ...
# 15261      2099600  Female     Denisa Duková              Houston
# 15262      2099618    Male   Justin Solórzano               Mclean
# 15263      2099758    Male    Svend Petrussen           Wilmington
# 15264      2099862  Female       Lorenza Rush            Riverside
# 15265      2099937    Male   Zygmunt Kaminski  Bloomfield Township
#
#                    State        Country      Continent    Birthday
# 0        South Australia      Australia      Australia    7/3/1939
# ...

# %%
# customer_dt.drop_duplicates(inplace=True)
customer_dt['Birthday']=pd.to_datetime(customer_dt['Birthday'])
customer_dt
# Out:
#        CustomerKey  Gender               Name                 City  \
# 0              301  Female      Lilly Harding       WANDEARAH EAST
# 1              325  Female       Madison Hull           MOUNT BUDD
# 2              554  Female      Claire Ferres            WINJALLOK
# 3              786    Male  Jai Poltpalingada         MIDDLE RIVER
# 4             1042    Male    Aidan Pankhurst        TAWONGA SOUTH
# ...            ...     ...                ...                  ...
# 15261      2099600  Female     Denisa Duková              Houston
# 15262      2099618    Male   Justin Solórzano               Mclean
# 15263      2099758    Male    Svend Petrussen           Wilmington
# 15264      2099862  Female       Lorenza Rush            Riverside
# 15265      2099937    Male   Zygmunt Kaminski  Bloomfield Township
#
#                    State        Country      Continent   Birthday
# 0        South Australia      Australia      Australia 1939-07-03
# ...

# %%
customer_dt.isnull().sum()
# Out:
# CustomerKey    0
# Gender         0
# Name           0
# City           0
# State          0
# Country        0
# Continent      0
# Birthday       0
# dtype: int64

# %%
customer_dt
# Out:
#        CustomerKey  Gender               Name                 City  \
# 0              301  Female      Lilly Harding       WANDEARAH EAST
# 1              325  Female       Madison Hull           MOUNT BUDD
# 2              554  Female      Claire Ferres            WINJALLOK
# 3              786    Male  Jai Poltpalingada         MIDDLE RIVER
# 4             1042    Male    Aidan Pankhurst        TAWONGA SOUTH
# ...            ...     ...                ...                  ...
# 15261      2099600  Female     Denisa Duková              Houston
# 15262      2099618    Male   Justin Solórzano               Mclean
# 15263      2099758    Male    Svend Petrussen           Wilmington
# 15264      2099862  Female       Lorenza Rush            Riverside
# 15265      2099937    Male   Zygmunt Kaminski  Bloomfield Township
#
#                    State        Country      Continent   Birthday
# 0        South Australia      Australia      Australia 1939-07-03
# ...

# %% [markdown]
# # EXCHANGE RATES

# %%
path=r"C:\Users\YAMINI RAVICHANDRAN\Documents\EDA\Exchange_Rates.csv"
exchange_rates_dt=pd.read_csv(path)
exchange_rates_dt
# Out:
#             Date Currency  Exchange
# 0       1/1/2015      USD    1.0000
# 1       1/1/2015      CAD    1.1583
# 2       1/1/2015      AUD    1.2214
# 3       1/1/2015      EUR    0.8237
# 4       1/1/2015      GBP    0.6415
# ...          ...      ...       ...
# 11210  2/20/2021      USD    1.0000
# 11211  2/20/2021      CAD    1.2610
# 11212  2/20/2021      AUD    1.2723
# 11213  2/20/2021      EUR    0.8238
# 11214  2/20/2021      GBP    0.7126
#
# [11215 rows x 3 columns]

# %%
exchange_rates_dt.isna().sum()
# Out:
# Date        0
# Currency    0
# Exchange    0
# dtype: int64

# %%
exchange_rates_dt.dtypes
# Out:
# Date         object
# Currency     object
# Exchange    float64
# dtype: object

# %%
exchange_rates_dt['Date']=pd.to_datetime(exchange_rates_dt['Date'])
exchange_rates_dt
# Out:
#             Date Currency  Exchange
# 0     2015-01-01      USD    1.0000
# 1     2015-01-01      CAD    1.1583
# 2     2015-01-01      AUD    1.2214
# 3     2015-01-01      EUR    0.8237
# 4     2015-01-01      GBP    0.6415
# ...          ...      ...       ...
# 11210 2021-02-20      USD    1.0000
# 11211 2021-02-20      CAD    1.2610
# 11212 2021-02-20      AUD    1.2723
# 11213 2021-02-20      EUR    0.8238
# 11214 2021-02-20      GBP    0.7126
#
# [11215 rows x 3 columns]

# %% [markdown]
# # PRODUCTS

# %%
path=r"C:\Users\YAMINI RAVICHANDRAN\Documents\EDA\Products.csv"
products_dt=pd.read_csv(path)
products_dt
# Out:
#       ProductKey                                   Product Name    Brand  \
# 0              1            Contoso 512MB MP3 Player E51 Silver  Contoso
# 1              2              Contoso 512MB MP3 Player E51 Blue  Contoso
# 2              3               Contoso 1G MP3 Player E100 White  Contoso
# 3              4              Contoso 2G MP3 Player E200 Silver  Contoso
# 4              5                 Contoso 2G MP3 Player E200 Red  Contoso
# ...          ...                                            ...      ...
# 2512        2513    Contoso Bluetooth Active Headphones L15 Red  Contoso
# 2513        2514  Contoso Bluetooth Active Headphones L15 White  Contoso
# 2514        2515             Contoso In-Line Coupler E180 White  Contoso
# 2515        2516             Contoso In-Line Coupler E180 Black  Contoso
# 2516        2517            Contoso In-Line Coupler E180 Silver  Contoso
#
#        Color Unit Cost USD Unit Price USD  SubcategoryKey  \
# ...

# %%
products_dt.isna().sum()
# Out:
# ProductKey        0
# Product Name      0
# Brand             0
# Color             0
# Unit Cost USD     0
# Unit Price USD    0
# SubcategoryKey    0
# Subcategory       0
# CategoryKey       0
# Category          0
# dtype: int64

# %%
products_dt['Unit Cost USD']=products_dt['Unit Cost USD'].str.replace('$','').str.replace(',','')
products_dt['Unit Price USD']=products_dt['Unit Price USD'].str.replace('$','').str.replace(',','')
products_dt
# Out:
#       ProductKey                                   Product Name    Brand  \
# 0              1            Contoso 512MB MP3 Player E51 Silver  Contoso
# 1              2              Contoso 512MB MP3 Player E51 Blue  Contoso
# 2              3               Contoso 1G MP3 Player E100 White  Contoso
# 3              4              Contoso 2G MP3 Player E200 Silver  Contoso
# 4              5                 Contoso 2G MP3 Player E200 Red  Contoso
# ...          ...                                            ...      ...
# 2512        2513    Contoso Bluetooth Active Headphones L15 Red  Contoso
# 2513        2514  Contoso Bluetooth Active Headphones L15 White  Contoso
# 2514        2515             Contoso In-Line Coupler E180 White  Contoso
# 2515        2516             Contoso In-Line Coupler E180 Black  Contoso
# 2516        2517            Contoso In-Line Coupler E180 Silver  Contoso
#
#        Color Unit Cost USD Unit Price USD  SubcategoryKey  CategoryKey  \
# ...

# %%
products_dt.drop_duplicates(inplace=True)

# %%
products_dt.drop(['Subcategory'],axis=1,inplace=True)

# %%
products_dt['Unit Price USD'][145]
# Out:
# '2899.99 '

# %% [markdown]
# # SALES

# %%
path=r"C:\Users\YAMINI RAVICHANDRAN\Documents\EDA\Sales.csv"
sales_dt=pd.read_csv(path)
sales_dt['Order Date']=pd.to_datetime(sales_dt['Order Date'])
sales_dt['Delivery Date']=pd.to_datetime(sales_dt['Delivery Date'])
sales_dt
# Out:
#        Order Number  Line Item Order Date Delivery Date  CustomerKey  \
# 0            366000          1 2016-01-01           NaT       265598
# 1            366001          1 2016-01-01    2016-01-13      1269051
# 2            366001          2 2016-01-01    2016-01-13      1269051
# 3            366002          1 2016-01-01    2016-01-12       266019
# 4            366002          2 2016-01-01    2016-01-12       266019
# ...             ...        ...        ...           ...          ...
# 62879       2243030          1 2021-02-20           NaT      1216913
# 62880       2243031          1 2021-02-20    2021-02-24       511229
# 62881       2243032          1 2021-02-20    2021-02-23       331277
# 62882       2243032          2 2021-02-20    2021-02-23       331277
# 62883       2243032          3 2021-02-20    2021-02-23       331277
#
#        StoreKey  ProductKey  Quantity Currency Code
# 0            10        1304         1           CAD
# ...

# %%
sales_dt.isna().sum()
# Out:
# Order Number         0
# Line Item            0
# Order Date           0
# Delivery Date    49719
# CustomerKey          0
# StoreKey             0
# ProductKey           0
# Quantity             0
# Currency Code        0
# dtype: int64

# %%
sales_dt['Delivery Date']=sales_dt['Delivery Date'].fillna(0)
sales_dt.isna().sum()
# Out:
# Order Number     0
# Line Item        0
# Order Date       0
# Delivery Date    0
# CustomerKey      0
# StoreKey         0
# ProductKey       0
# Quantity         0
# Currency Code    0
# dtype: int64

# %%
sales_dt
# Out:
#        Order Number  Line Item Order Date        Delivery Date  CustomerKey  \
# 0            366000          1 2016-01-01                    0       265598
# 1            366001          1 2016-01-01  2016-01-13 00:00:00      1269051
# 2            366001          2 2016-01-01  2016-01-13 00:00:00      1269051
# 3            366002          1 2016-01-01  2016-01-12 00:00:00       266019
# 4            366002          2 2016-01-01  2016-01-12 00:00:00       266019
# ...             ...        ...        ...                  ...          ...
# 62879       2243030          1 2021-02-20                    0      1216913
# 62880       2243031          1 2021-02-20  2021-02-24 00:00:00       511229
# 62881       2243032          1 2021-02-20  2021-02-23 00:00:00       331277
# 62882       2243032          2 2021-02-20  2021-02-23 00:00:00       331277
# 62883       2243032          3 2021-02-20  2021-02-23 00:00:00       331277
#
#        StoreKey  ProductKey  Quantity Currency Code
# ...

# %% [markdown]
# # STORES

# %%
path=r"C:\Users\YAMINI RAVICHANDRAN\Documents\EDA\Stores.csv"
stores_dt=pd.read_csv(path)
stores_dt['Open Date']=pd.to_datetime(stores_dt['Open Date'])
stores_dt['Square Meters']=stores_dt['Square Meters'].fillna(0)
stores_dt
# Out:
#     StoreKey        Country                         State  Square Meters  \
# 0          1      Australia  Australian Capital Territory          595.0
# 1          2      Australia            Northern Territory          665.0
# 2          3      Australia               South Australia         2000.0
# 3          4      Australia                      Tasmania         2000.0
# 4          5      Australia                      Victoria         2000.0
# ..       ...            ...                           ...            ...
# 62        63  United States                          Utah         2000.0
# 63        64  United States                 Washington DC         1330.0
# 64        65  United States                 West Virginia         1785.0
# 65        66  United States                       Wyoming          840.0
# 66         0         Online                        Online            0.0
#
#     Open Date
# 0  2008-01-01
# 1  2008-01-12
# 2  2012-01-07
# 3  2010-01-01
# ...

# %% [markdown]
# # CREATE SQL DATABASE

# %%
# !pip install mysql-connector-python
# Out:
# ...
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from mysql import connector
connection = connector.connect(
    host = "localhost",
    user="root",
    password = "Umaravidaryam@2810" ,
    database="Dataspark"
)

connection

# %%
cursor = connection.cursor()
cursor

# %%
query='create database if not exists Dataspark'
cursor.execute(query)

# %%
query='''Create table if not exists customer_details
        (CustomerKey INT,
        Gender VARCHAR(255),
        Name VARCHAR(255),
        City VARCHAR(255),
        State VARCHAR(255),
        Country VARCHAR(255),
        Continent VARCHAR(255),
        Birthday VARCHAR(255))'''

cursor.execute(query)

# %%
query='''insert into customer_details
         (CustomerKey,
         Gender,
         Name,
         City,
         State,
         Country,
         Continent,
         Birthday) values(%s,%s,%s,%s,%s,%s,%s,%s)'''
data=[tuple(row) for row in customer_dt.values]
cursor.executemany(query,data)

# %%
query='''create table if not exists exchange_rates_details(
         Date VARCHAR(255),
         Currency VARCHAR(255),
         Exchange VARCHAR(255)
         )'''
cursor.execute(query)

# %%
query=''' insert into exchange_rates_details(
          Date,
          Currency,
          Exchange) values(%s,%s,%s)'''
data=exchange_rates_dt.values.tolist()
cursor.executemany(query,data)

# %%
query='''create table if not exists products_details(
         ProductKey INT,
         Product_Name VARCHAR(255),
         Brand VARCHAR(255),
         Color VARCHAR(255),
         Unit_Cost_USD FLOAT,
         Unit_Price_USD FLOAT,
         SubcategoryKey VARCHAR(255),
         CategoryKey VARCHAR(255),
         Category VARCHAR(255))'''
cursor.execute(query)

# %%
query='''insert into products_details(
         ProductKey,
         Product_Name,
         Brand,
         Color,
         Unit_Cost_USD,
         Unit_Price_USD,
         SubcategoryKey,
         CategoryKey,
         Category) values(%s,%s,%s,%s,%s,%s,%s,%s,%s)'''
data=products_dt.values.tolist()
cursor.executemany(query,data)

# %%
query='''create table sales(
         Order_Number INT,
         Line_Item INT,
         Order_Date VARCHAR(255),
         Delivery_Date VARCHAR(255),
         CustomerKey INT,
         StoreKey INT,
         ProductKey INT,
         Quantity INT,
         Currency_Code VARCHAR(255))'''
cursor.execute(query)

# %%
query='''insert into  sales(
         Order_Number,
         Line_Item,
         Order_Date,
         Delivery_Date,
         CustomerKey,
         StoreKey,
         ProductKey,
         Quantity,
         Currency_Code) values(%s,%s,%s,%s,%s,%s,%s,%s,%s)'''
data=sales_dt.values.tolist()
cursor.executemany(query,data)

# %%
query='''create table if not exists stores_details(
         StoreKey INT,
         Country VARCHAR(255),
         State VARCHAR(255),
         Square_Meters FLOAT,
         Open_Date VARCHAR(255))'''
cursor.execute(query)

# %%
query='''insert into stores_details(
         StoreKey,
         Country,
         State,
         Square_Meters,
         Open_Date) values(%s,%s,%s,%s,%s)'''
data=stores_dt.values.tolist()
cursor.executemany(query,data)
connection.commit()

# %%
query = 'SHOW TABLES'
cursor.execute(query)


tables = cursor.fetchall()


for table in tables:
    print(table[0])
# Out:
# customer_details
# exchange_rates_details
# products_details
# sales
# stores_details

# %%
query='select * from stores_details'
cursor.execute(query)

rows = cursor.fetchall()


for row in rows:
    print(row)
# Out:
# (1, 'Australia', 'Australian Capital Territory', 595.0, '2008-01-01 00:00:00')
# (2, 'Australia', 'Northern Territory', 665.0, '2008-01-12 00:00:00')
# (3, 'Australia', 'South Australia', 2000.0, '2012-01-07 00:00:00')
# (4, 'Australia', 'Tasmania', 2000.0, '2010-01-01 00:00:00')
# (5, 'Australia', 'Victoria', 2000.0, '2015-12-09 00:00:00')
# (6, 'Australia', 'Western Australia', 2000.0, '2010-01-01 00:00:00')
# (7, 'Canada', 'New Brunswick', 1105.0, '2007-05-07 00:00:00')
# (8, 'Canada', 'Newfoundland and Labrador', 2105.0, '2014-07-02 00:00:00')
# (9, 'Canada', 'Northwest Territories', 1500.0, '2005-03-04 00:00:00')
# (10, 'Canada', 'Nunavut', 1210.0, '2015-04-04 00:00:00')
# (11, 'Canada', 'Yukon', 1210.0, '2009-06-03 00:00:00')
# (12, 'France', 'Basse-Normandie', 350.0, '2012-06-06 00:00:00')
# (13, 'France', 'Corse', 245.0, '2013-06-07 00:00:00')
# (14, 'France', 'Franche-Comté', 350.0, '2009-12-15 00:00:00')
# (15, 'France', 'La Réunion', 400.0, '2015-01-01 00:00:00')
# ...

# %%
query='''insert into stores_details(
         StoreKey,
         Country,
         State,
         Square_Meters,
         Open_Date) values(%s,%s,%s,%s,%s)'''
data=stores_dt.values.tolist()
cursor.executemany(query,data)
